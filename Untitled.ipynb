# %%
import pandas as pd
import matplotlib as mplstyle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

mplstyle.rcParams['pdf.fonttype'] = 42



pinellas_palette = ["#3498db", "#e74c3c"]
race_palette = ["#1b9e77", "#d95f02"]

# %%
elementary = pd.read_csv("/mnt/c/Users/ralph/Desktop/FL_elementaries.csv")

# %%
g  = plt.scatter(
            x=elementary['percent_passing_reading'], 
            y=elementary['percent_passing_math'], 
            s=elementary['total_enrollment']/10,
            alpha=0.4)
